# %% [markdown]
# # **Credit Card Customer Clustering Analysis**

# %% [markdown]
# ### Abstract

# %% [markdown]
# This project addresses the challenge of designing effective marketing strategies for financial institutions by implementing an automated customer segmentation framework. Using a dataset of approximately 9,000 active credit card holders, we applied the **K-Means Clustering** algorithm to categorize users based on their spending and repayment behaviors. By refining feature selection through **Trimmed Variance** and evaluating model stability via **Inertia** and **Silhouette Scores**, we successfully identified three distinct segments. The results provide a data-driven foundation for a tiered credit card marketing campaign, enabling the transition from generic outreach to hyper-personalized product offerings (Platinum, Gold, and Silver).

# %% [markdown]
# ### 1. Introduction

# %% [markdown]
# In the modern banking sector, the ability to understand and predict customer needs is a critical competitive advantage. Financial institutions often launch broad marketing campaigns that fail to resonate with diverse user groups, leading to inefficient resource allocation and low conversion rates.
#
# The primary objective of this project is to optimize an upcoming **Credit Card Marketing Campaign** by uncovering hidden patterns in customer data. Instead of manual categorization, we utilize **Unsupervised Machine Learning** to let the data speak for itself. By clustering customers into groups with similar financial profiles, we can tailor credit limits, interest rates, and reward programs to match the specific habits of each segment. Whether it's identifying high-spending "Elite" users or routine "Everyday" consumers, this project demonstrates how algorithmic segmentation can transform raw financial data into a powerful tool for customer engagement and business growth.

# %% [markdown]
# ### 2. Import Data

# %%
# Import libraries
import warnings
import pandas as pd
import plotly.express as px
from scipy.stats.mstats import trimmed_var
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
# Read data into Dataframe `df`
df = pd.read_csv("CC GENERAL.csv")
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %% [markdown]
# ### 3. Exploring Data Analysis

# %%
df.drop(columns={"CUST_ID"}, inplace=True)

# %%
# Dataframe statistics
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
# Checking Missing Values
df.isnull().sum() / len(df)
# Out:
# BALANCE                             0.000000
# BALANCE_FREQUENCY                   0.000000
# PURCHASES                           0.000000
# ONEOFF_PURCHASES                    0.000000
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.000000
# PURCHASES_FREQUENCY                 0.000000
# ONEOFF_PURCHASES_FREQUENCY          0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.000000
# CASH_ADVANCE_TRX                    0.000000
# PURCHASES_TRX                       0.000000
# CREDIT_LIMIT                        0.000112
# PAYMENTS                            0.000000
# MINIMUM_PAYMENTS                    0.034972
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              0.000000
# dtype: float64

# %%
df.loc[(df['MINIMUM_PAYMENTS'].isnull()==True),'MINIMUM_PAYMENTS']=df['MINIMUM_PAYMENTS'].mean()
df.loc[(df['CREDIT_LIMIT'].isnull()==True),'CREDIT_LIMIT']=df['CREDIT_LIMIT'].mean()

# %%
# Check for duplicate Values
df.duplicated().sum()
# Out:
# 0

# %%
# Calculate variance, get 10 largest features
top_ten_var = df.var().sort_values().tail(10)
top_ten_var
# Out:
# CASH_ADVANCE_TRX          4.657580e+01
# PURCHASES_TRX             6.179027e+02
# INSTALLMENTS_PURCHASES    8.178274e+05
# ONEOFF_PURCHASES          2.755228e+06
# BALANCE                   4.332775e+06
# CASH_ADVANCE              4.398096e+06
# PURCHASES                 4.565208e+06
# MINIMUM_PAYMENTS          5.431641e+06
# PAYMENTS                  8.381394e+06
# CREDIT_LIMIT              1.323950e+07
# dtype: float64

# %%
# Create horizontal bar chart of `top_ten_var`
fig = px.bar(
    x = top_ten_var,
    y = top_ten_var.index,
    title = "High Variance Features"
)

fig.update_layout(xaxis_title = "Variance", yaxis_title = "Feature")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Create a boxplot of `NHNFIN`
fig = px.box(
    data_frame = df,
    x = "CREDIT_LIMIT",
    title = "Distribution of Credit Cards Limits"
    )
fig.update_layout(xaxis_title = "Value [$]")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Calculate trimmed variance
top_ten_trim_var = df.apply(trimmed_var, limits=(0.1,0.1)).sort_values().tail(10)
top_ten_trim_var
# Out:
# CASH_ADVANCE_TRX          6.210728e+00
# PURCHASES_TRX             8.462990e+01
# INSTALLMENTS_PURCHASES    8.415305e+04
# MINIMUM_PAYMENTS          1.541693e+05
# ONEOFF_PURCHASES          1.582269e+05
# PURCHASES                 3.902004e+05
# CASH_ADVANCE              6.109811e+05
# PAYMENTS                  7.937212e+05
# BALANCE                   1.131014e+06
# CREDIT_LIMIT              5.255708e+06
# dtype: float64

# %%
# Create horizontal bar chart of `top_ten_trim_var`
fig = px.bar(
    x = top_ten_trim_var,
    y = top_ten_trim_var.index,
    title = "High Variance Features"
    )

fig.update_layout(xaxis_title ="Trimmed Variance", yaxis_title="Feature")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
high_var_cols = top_ten_trim_var.tail(5).index.to_list()
high_var_cols
# Out:
# ['PURCHASES', 'CASH_ADVANCE', 'PAYMENTS', 'BALANCE', 'CREDIT_LIMIT']

# %% [markdown]
# ### 4. Split Data

# %%
X = df[high_var_cols]
print("X shape:", X.shape)
X.head()
# Out:
# X shape: (8950, 5)
#    PURCHASES  CASH_ADVANCE     PAYMENTS      BALANCE  CREDIT_LIMIT
# 0      95.40      0.000000   201.802084    40.900749        1000.0
# 1       0.00   6442.945483  4103.032597  3202.467416        7000.0
# 2     773.17      0.000000   622.066742  2495.148862        7500.0
# 3    1499.00    205.788017     0.000000  1666.670542        7500.0
# 4      16.00      0.000000   678.334763   817.714335        1200.0

# %% [markdown]
# ### 5. Build model

# %%
X_summary = X.aggregate(["mean","std"]).astype(int)
X_summary
# Out:
#       PURCHASES  CASH_ADVANCE  PAYMENTS  BALANCE  CREDIT_LIMIT
# mean       1003           978      1733     1564          4494
# std        2136          2097      2895     2081          3638

# %%
# Instantiate transformer
ss = StandardScaler()

# Transform `X`
X_scaled_data = ss.fit_transform(X)

# Put `X_scaled_data` into DataFrame
X_scaled = pd.DataFrame(X_scaled_data, columns=X.columns)

print("X_scaled shape:", X_scaled.shape)
X_scaled.head()
# Out:
# X_scaled shape: (8950, 5)
#    PURCHASES  CASH_ADVANCE  PAYMENTS   BALANCE  CREDIT_LIMIT
# 0  -0.424900     -0.466786 -0.528979 -0.731989     -0.960433
# 1  -0.469552      2.605605  0.818642  0.786961      0.688639
# 2  -0.107668     -0.466786 -0.383805  0.447135      0.826062
# 3   0.232058     -0.368653 -0.598688  0.049099      0.826062
# 4  -0.462063     -0.466786 -0.364368 -0.358775     -0.905464

# %%
X_scaled_summary = X_scaled.aggregate(["mean","std"]).astype(int)
X_scaled_summary
# Out:
#       PURCHASES  CASH_ADVANCE  PAYMENTS  BALANCE  CREDIT_LIMIT
# mean          0             0         0        0             0
# std           1             1         1        1             1

# %%
n_clusters = range(2,13)
inertia_errors = []
silhouette_scores = []

# Add `for` loop to train model and calculate inertia, silhouette score.
for k in n_clusters:
    #Build model
    model = make_pipeline(
        StandardScaler(),
        KMeans(n_clusters=k, random_state=42)
        )
    #Train model
    model.fit(X)

    #Calculate inertia
    inertia_errors.append(model.named_steps['kmeans'].inertia_)

    #Calculate silhouette score
    silhouette_scores.append(
        silhouette_score(X, model.named_steps['kmeans'].labels_)
        )


print("Inertia:", inertia_errors[:3])
print()
print("Silhouette Scores:", silhouette_scores[:3])
# Out:
# Inertia: [31229.30242026945, 25753.568706692993, 21904.80627378999]
#
# Silhouette Scores: [0.5493067534212036, 0.49545339522172394, 0.43590944455724895]

# %%
# Create line plot of `inertia_errors` vs `n_clusters`
fig = px.line(
    x=n_clusters, y=inertia_errors, title="K-Mean Model: Inertia vs Number of Clusters"
    )

fig.update_layout(xaxis_title="Number of Clusters", yaxis_title="Inertia")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Create a line plot of `silhouette_scores` vs `n_clusters`
fig = px.line(
    x=n_clusters, y=silhouette_scores, title="K-Means Model: Silhouette Score vs Number of Clusters"
    )
fig.update_layout(xaxis_title="Number of Clusters", yaxis_title="Silhouette score")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
final_model = make_pipeline(
    StandardScaler(),
    KMeans(n_clusters=3, random_state=42)
)
final_model.fit(X)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('kmeans', KMeans(n_clusters=3, random_state=42))])

# %% [markdown]
# ### 6. Model Evaluation

# %%
labels = final_model.named_steps["kmeans"].labels_
print(labels[:5])
# Out:
# [2 0 2 2 2]

# %%
xgb = X.groupby(labels).mean()
xgb
# Out:
#       PURCHASES  CASH_ADVANCE      PAYMENTS      BALANCE  CREDIT_LIMIT
# 0   1407.832604   3064.835456   3271.959417  4509.618327   9065.326799
# 1  11083.715591   5111.941431  18150.407047  4720.766695  12378.740157
# 2    731.556016    425.493106   1088.194476   830.609660   3302.616848

# %%
# Create side-by-side bar chart of `xgb`
fig = px.bar(
    xgb,
    barmode="group",
    title="Mean Household Finances by Cluster"
)
fig.update_layout(xaxis_title="Cluster", yaxis_title="Value [$]")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Instantiate transformer
pca = PCA(n_components=2, random_state=42)

# Transform `X`
X_t = pca.fit_transform(X)

# Put `X_t` into DataFrame
X_pca = pd.DataFrame(X_t, columns= ["PC1","PC2"])

print("X_pca shape:", X_pca.shape)
X_pca.head()
# Out:
# X_pca shape: (8950, 2)
#            PC1          PC2
# 0 -4254.981747   733.218339
# 1  4533.422706  -149.834778
# 2  1648.101022 -2768.622856
# 3  1336.657807 -2741.260915
# 4 -3660.627187   779.205904

# %%
# Create scatter plot of `PC2` vs `PC1`
fig = px.scatter(
    data_frame=X_pca,
    x= "PC1",
    y="PC2",
    color=labels.astype(str),
    title= "PCA Representation of Clusters"
)
fig.update_layout(xaxis_title="PC1", yaxis_title="PC2")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Workflow Summary and Future Work

# %% [markdown]
# #### **Workflow Summary**

# %% [markdown]
# This project followed a structured data science pipeline to transform raw banking data into a strategic marketing tool. The journey began with **rigorous data profiling** and mean imputation to handle missing values, followed by a sophisticated **feature selection process** using **Trimmed Variance** to filter out noise from outliers. By scaling the data and applying the **K-Means algorithm**, we successfully mapped the customer base into three actionable tiers (Platinum, Gold, and Silver). The model's validity was confirmed through **Inertia and Silhouette analysis**, and visualized using **PCA** to ensure clear cluster separation, providing a reliable foundation for targeted credit card campaigns.

# %% [markdown]
# #### **Future Work**

# %% [markdown]
# To further enhance the precision and business value of this segmentation, the following improvements are proposed:
#
# * **Dynamic Clustering:** Implement a pipeline that periodically re-clusters customers to capture shifting spending behaviors over time.
# * **Supervised Hybrid Model:** Use the cluster labels as a target variable to train a classifier (e.g., Random Forest) for real-time categorization of new applicants.
# * **Deep Feature Engineering:** Incorporate "Recency, Frequency, and Monetary" (RFM) analysis to gain deeper insights into customer loyalty and churn risk.
# * **Hyperparameter Optimization:** Explore advanced algorithms like **DBSCAN** or **Hierarchical Clustering** to better handle the non-linear distribution and extreme outliers present in financial data.
